# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
customers = pd.read_csv("data/raw/olist_customers_dataset.csv")
orders = pd.read_csv("data/raw/olist_orders_dataset.csv")
products = pd.read_csv("data/raw/olist_products_dataset.csv")
order_items = pd.read_csv("data/raw/olist_order_items_dataset.csv")
sellers = pd.read_csv("data/raw/olist_sellers_dataset.csv")
payments = pd.read_csv("data/raw/olist_order_payments_dataset.csv")
reviews = pd.read_csv("data/raw/olist_order_reviews_dataset.csv")

# %%
customers.head()

customers.info()

customers.describe(include='all')

customers.isnull().sum()

customers.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
# np.int64(0)

# %%
# how many orders:
orders["order_id"].nunique()
# Out:
# 99441

# %%
# how many customers:
customers["customer_unique_id"].nunique()
# Out:
# 96096

# %%
# how many products:
products["product_id"].nunique()
# Out:
# 32951

# %%
# Approximate total revenue
order_items["price"].sum()
# Out:
# np.float64(13591643.700000003)

# %%
# Top customer states
customers["customer_state"].value_counts().head(10)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# Name: count, dtype: int64

# %%
customers["customer_state"].value_counts().head(10).plot(kind="bar")
plt.title("Top customer states")
plt.show()

# %%
# top sellers states
sellers["seller_state"].value_counts().head(10).plot(kind="bar")
plt.title("Top seller states")
plt.show()

# %%
# order status:
orders["order_status"].value_counts().plot(kind="bar")
plt.title("Order Status")
plt.show()

# %%
products["product_category_name"].value_counts().head(10)
# Out:
# product_category_name
# cama_mesa_banho           3029
# esporte_lazer             2867
# moveis_decoracao          2657
# beleza_saude              2444
# utilidades_domesticas     2335
# automotivo                1900
# informatica_acessorios    1639
# brinquedos                1411
# relogios_presentes        1329
# telefonia                 1134
# Name: count, dtype: int64

# %%
# Average product price
order_items["price"].mean()
# Out:
# np.float64(120.65373901464716)

# %%
# Average freight cost
order_items["freight_value"].mean()
# Out:
# np.float64(19.990319928983578)

# %%
# Payment methods
payments["payment_type"].value_counts()
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %%
payments["payment_type"].value_counts().plot(kind="bar")
plt.title("Payment methods")
plt.show()

# %%
# Average review score
reviews["review_score"].mean()
# Out:
# np.float64(4.08642062404257)

# %%
reviews["review_score"].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Observations:
# ###### The dataset contains 99441 orders
# ###### Most customers are from state SP.
# ###### Most sellers are also located in SP.
# ###### The average review score is 4.08642062404257.
# ###### Credit card is the most common payment method.
# ###### Total revenue is approximately   13591643.700000003 BRL.
# ######  Only a few columns contain missing values.
# ###### No significant duplicate records were found.
